# %%
import pandas as pd
from urllib.request import urlopen
from bs4 import BeautifulSoup
import numpy as np

# %%
roy_table = pd.read_csv('ROY.csv')
print(roy_table.head())
# Out:
#     Season   Lg                    Player Voting  Age   Tm   G    MP   PTS  \
# 0  2021-22  NBA  Scottie Barnes\barnesc01    (V)   20  TOR  74  35.4  15.3
# 1  2020-21  NBA      LaMelo Ball\ballla01    (V)   19  CHO  51  28.8  15.7
# 2  2019-20  NBA       Ja Morant\moranja01    (V)   20  MEM  67  31.0  17.8
# 3  2018-19  NBA     Luka Dončić\doncilu01    (V)   19  DAL  72  32.2  21.2
# 4  2017-18  NBA     Ben Simmons\simmobe01    (V)   21  PHI  81  33.7  15.8
#
#    TRB  AST  STL  BLK    FG%    3P%    FT%   WS  WS/48
# 0  7.5  3.5  1.1  0.7  0.492  0.301  0.735  6.6  0.122
# 1  5.9  6.1  1.6  0.4  0.436  0.352  0.758  2.8  0.093
# 2  3.9  7.3  0.9  0.3  0.477  0.335  0.776  3.8  0.088
# 3  7.8  6.0  1.1  0.3  0.427  0.327  0.713  4.9  0.101
# 4  8.1  8.2  1.7  0.9  0.545  0.000  0.560  9.2  0.162

# %%
player_list = roy_table['Player'].tolist()
player_seasons = roy_table['Season'].tolist()
player_names = []
player_links = []
for player in player_list:
    player_links.append(player.split('\\')[1])
    player_names.append(player.split('\\')[0])

print(player_names)
print(player_links)
print(player_seasons)
# Out:
# ['Scottie Barnes', 'LaMelo Ball', 'Ja Morant', 'Luka Dončić', 'Ben Simmons', 'Malcolm Brogdon', 'Karl-Anthony Towns', 'Andrew Wiggins', 'Michael Carter-Williams', 'Damian Lillard', 'Kyrie Irving', 'Blake Griffin', 'Tyreke Evans', 'Derrick Rose', 'Kevin Durant', 'Brandon Roy', 'Chris Paul', 'Emeka Okafor', 'LeBron James', "Amar'e Stoudemire", 'Pau Gasol', 'Mike Miller', 'Steve Francis (Tie)', 'Elton Brand (Tie)', 'Vince Carter', 'Tim Duncan', 'Allen Iverson', 'Damon Stoudamire', 'Grant Hill (Tie)', 'Jason Kidd (Tie)', 'Chris Webber', "Shaquille O'Neal", 'Larry Johnson', 'Derrick Coleman', 'David Robinson', 'Mitch Richmond', 'Mark Jackson', 'Chuck Person', 'Patrick Ewing', 'Michael Jordan', 'Ralph Sampson', 'Terry Cummings', 'Buck Williams', 'Darrell Griffith', 'Larry Bird', 'Phil Ford', 'Walter Davis', 'Adrian Dantley', 'Alvan Adams', 'Jamaal Wilkes', 'Ernie DiGregorio', 'Bob McAdoo', 'Sidney Wicks', 'Geoff Petrie (Tie)', 'Dave Cowens (Tie)', 'Kareem Abdul-Jabbar', 'Wes Unseld', 'Earl Monroe', 'Dave Bing', 'Rick Barry', 'Willis Reed', 'Jerry Lucas', 'Terry Dischinger', 'Walt Bellamy', 'Oscar Robertson', 'Wilt Chamberlain', 'Elgin Baylor', 'Woody Sauldsberry', 'Tom Heinsohn', 'Maurice Stokes', 'Bob Pettit', 'Ray Felix', 'Monk Meineke', 'Mel Hutchins (Tie) *', 'Bill Tosheff (Tie) *', 'Paul Arizin *', 'Alex Groza *', 'Howie Shannon *', 'Paul Hoffman *']
# ['barnesc01', 'ballla01', 'moranja01', 'doncilu01', 'simmobe01', 'brogdma01', 'townska01', 'wiggian01', 'cartemi01', 'lillada01', 'irvinky01', 'griffbl01', 'evansty01', 'rosede01', 'duranke01', 'roybr01', 'paulch01', 'okafoem01', 'jamesle01', 'stoudam01', 'gasolpa01', 'millemi01', 'francst01', 'brandel01', 'cartevi01', 'duncati01', 'iversal01', 'stoudda01', 'hillgr01', 'kiddja01', 'webbech01', 'onealsh01', 'johnsla02', 'colemde01', 'robinda01', 'richmmi01', 'jacksma01', 'persoch01', 'ewingpa01', 'jordami01', 'sampsra01', 'cummite01', 'willibu01', 'griffda01', 'birdla01', 'fordph01', 'daviswa03', 'dantlad01', 'adamsal01', 'wilkeja01', 'digreer01', 'mcadobo01', 'wickssi01', 'petrige01', 'cowenda01', 'abdulka01', 'unselwe01', 'monroea01', 'bingda01', 'barryri01', 'reedwi01', 'lucasje01', 'dischte01', 'bellawa01', 'roberos01', 'chambwi01', 'bayloel01', 'sauldwo01', 'heinsto01', 'stokema01', 'pettibo01', 'felixra01', 'meinemo01', 'hutchme01', 'toshebi01', 'arizipa01', 'grozaal01', 'shannho01', 'hoffmpa01']
# ['2021-22', '2020-21', '2019-20', '2018-19', '2017-18', '2016-17', '2015-16', '2014-15', '2013-14', '2012-13', '2011-12', '2010-11', '2009-10', '2008-09', '2007-08', '2006-07', '2005-06', '2004-05', '2003-04', '2002-03', '2001-02', '2000-01', '1999-00', '1999-00', '1998-99', '1997-98', '1996-97', '1995-96', '1994-95', '1994-95', '1993-94', '1992-93', '1991-92', '1990-91', '1989-90', '1988-89', '1987-88', '1986-87', '1985-86', '1984-85', '1983-84', '1982-83', '1981-82', '1980-81', '1979-80', '1978-79', '1977-78', '1976-77', '1975-76', '1974-75', '1973-74', '1972-73', '1971-72', '1970-71', '1970-71', '1969-70', '1968-69', '1967-68', '1966-67', '1965-66', '1964-65', '1963-64', '1962-63', '1961-62', '1960-61', '1959-60', '1958-59', '1957-58', '1956-57', '1955-56', '1954-55', '1953-54', '1952-53', '1951-52', '1951-52', '1950-51', '1949-50', '1948-49', '1947-48']

# %%
roy_stats = []
for i in range(30):

    html_text = urlopen(f'https://www.basketball-reference.com/players/{player_links[i][0]}/{player_links[i]}.html')
    print(f'https://www.basketball-reference.com/players/{player_links[i]}/{player_links[i]}.html')
    print(player_seasons[i])
    soup = BeautifulSoup(html_text.read(), 'lxml')
    basic_table = soup.find('table', {'id': 'per_game'})
    advanced_table = soup.find('table', {'id': 'advanced'})

    basic_table = pd.read_html(str(basic_table))[0]
    advanced_table = pd.read_html(str(advanced_table))[0]

    basic_table = basic_table[basic_table['Season'] == player_seasons[i]]
    advanced_table = advanced_table[advanced_table['Season'] == player_seasons[i]]

    roy_stats.append([basic_table['PTS'].tolist()[0], basic_table['AST'].tolist()[0], basic_table['TRB'].tolist()[
                     0], advanced_table['TS%'].tolist()[0], advanced_table['BPM'].tolist()[0]])

roy_stats = np.array(roy_stats).astype(float)
print(roy_stats)
print(len(roy_stats))
# Out:
# https://www.basketball-reference.com/players/barnesc01/barnesc01.html
# 2021-22
# https://www.basketball-reference.com/players/ballla01/ballla01.html
# 2020-21
# https://www.basketball-reference.com/players/moranja01/moranja01.html
# 2019-20
# https://www.basketball-reference.com/players/doncilu01/doncilu01.html
# 2018-19
# https://www.basketball-reference.com/players/simmobe01/simmobe01.html
# 2017-18
# https://www.basketball-reference.com/players/brogdma01/brogdma01.html
# 2016-17
# https://www.basketball-reference.com/players/townska01/townska01.html
# 2015-16
# https://www.basketball-reference.com/players/wiggian01/wiggian01.html
# 2014-15
# https://www.basketball-reference.com/players/cartemi01/cartemi01.html
# 2013-14
# https://www.basketball-reference.com/players/lillada01/lillada01.html
# 2012-13
# https://www.basketball-reference.com/players/irvinky01/irvinky01.html
# 2011-12
# https://www.basketball-reference.com/players/griffbl01/griffbl01.html
# 2010-11
# https://www.basketball-reference.com/players/evansty01/evansty01.html
# 2009-10
# https://www.basketball-reference.com/players/rosede01/rosede01.html
# 2008-09
# https://www.basketball-reference.com/players/duranke01/duranke01.html
# 2007-08
# https://www.basketball-reference.com/players/roybr01/roybr01.html
# 2006-07
# https://www.basketball-reference.com/players/paulch01/paulch01.html
# 2005-06
# https://www.basketball-reference.com/players/okafoem01/okafoem01.html
# 2004-05
# https://www.basketball-reference.com/players/jamesle01/jamesle01.html
# 2003-04
# https://www.basketball-reference.com/players/stoudam01/stoudam01.html
# 2002-03
# https://www.basketball-reference.com/players/gasolpa01/gasolpa01.html
# 2001-02
# https://www.basketball-reference.com/players/millemi01/millemi01.html
# 2000-01
# https://www.basketball-reference.com/players/francst01/francst01.html
# 1999-00
# https://www.basketball-reference.com/players/brandel01/brandel01.html
# 1999-00
# https://www.basketball-reference.com/players/cartevi01/cartevi01.html
# 1998-99
# https://www.basketball-reference.com/players/duncati01/duncati01.html
# 1997-98
# https://www.basketball-reference.com/players/iversal01/iversal01.html
# 1996-97
# https://www.basketball-reference.com/players/stoudda01/stoudda01.html
# 1995-96
# https://www.basketball-reference.com/players/hillgr01/hillgr01.html
# 1994-95
# https://www.basketball-reference.com/players/kiddja01/kiddja01.html
# 1994-95
# [[15.3    3.5    7.5    0.552  0.9  ]
#  [15.7    6.1    5.9    0.539  1.8  ]
#  [17.8    7.3    3.9    0.556  0.3  ]
#  [21.2    6.     7.8    0.545  3.9  ]
#  [15.8    8.2    8.1    0.557  4.5  ]
#  [10.2    4.2    2.8    0.555 -0.4  ]
#  [18.3    2.    10.5    0.59   2.2  ]
#  [16.9    2.1    4.6    0.517 -2.4  ]
#  [16.7    6.3    6.2    0.48  -0.5  ]
#  [19.     6.5    3.1    0.546  0.3  ]
#  [18.5    5.4    3.7    0.566  4.1  ]
#  [22.5    3.8   12.1    0.549  2.6  ]
#  [20.1    5.8    5.3    0.529  1.3  ]
#  [16.8    6.3    3.9    0.516 -0.4  ]
#  [20.3    2.4    4.4    0.519 -0.1  ]
#  [16.8    4.     4.4    0.548  2.   ]
#  [16.1    7.8    5.1    0.546  5.2  ]
#  [15.1    0.9   10.9    0.479 -2.   ]
#  [20.9    5.9    5.5    0.488  1.7  ]
#  [13.5    1.     8.8    0.53  -1.4  ]
#  [17.6    2.7    8.9    0.566  1.7  ]
#  [11.9    1.7    4.     0.541 -0.2  ]
#  [18.     6.6    5.3    0.543  2.   ]
#  [20.1    1.9   10.     0.528  1.3  ]
#  [18.3    3.     5.7    0.516  2.8  ]
#  [21.1    2.7   11.9    0.577  4.6  ]
#  [23.5    7.5    4.1    0.513  0.9  ]
#  [19.     9.3    4.     0.528  0.1  ]
#  [19.9    5.     6.4    0.541  2.   ]
#  [11.7    7.7    5.4    0.471  1.2  ]]
# 30

# %%
from random import randint
season = 2021
non_roy_stats = []
while season >= 1991:
    print(season)
    html_text = urlopen(
        f'https://www.basketball-reference.com/leagues/NBA_{season}_per_game.html')
    soup = BeautifulSoup(html_text.read(), 'lxml')
    basic_table = soup.find('table', {'id': 'per_game_stats'})
    basic_table = pd.read_html(str(basic_table))[0]

    html_text = urlopen(
        f'https://www.basketball-reference.com/leagues/NBA_{season}_advanced.html')
    soup = BeautifulSoup(html_text.read(), 'lxml')
    advanced_table = soup.find('table', {'id': 'advanced_stats'})
    advanced_table = pd.read_html(str(advanced_table))[0]

    basic_table = basic_table[basic_table['Player'] != 'Player']
    advanced_table = advanced_table[advanced_table['Player'] != 'Player']

    basic_table = basic_table[~basic_table['Player'].isin(player_names)]
    advanced_table = advanced_table[~advanced_table['Player'].isin(
        player_names)]

    table_length = len(basic_table)

    for i in range(5):
        random_player_index = randint(0, table_length - 1)
        basic_stats = basic_table.iloc[random_player_index]
        advanced_stats = advanced_table.iloc[random_player_index]
        non_roy_stats.append([basic_stats['PTS'], basic_stats['AST'], basic_stats['TRB'],advanced_stats['TS%'], advanced_stats['BPM']])
    season-=1
non_roy_stats = np.array(non_roy_stats).astype(float)
print(non_roy_stats)
# Out:
# 2021
# 2020
# 2019
# 2018
# 2017
# 2016
# 2015
# 2014
# 2013
# 2012
# 2011
# 2010
# 2009
# 2008
# 2007
# 2006
# 2005
# 2004
# 2003
# 2002
# 2001
# 2000
# 1999
# 1998
# 1997
# 1996
# 1995
# 1994
# 1993
# 1992
# 1991
# [[  5.4     1.2     5.8     0.612  -0.1  ]
#  [  7.4     1.2     1.5     0.564  -3.5  ]
#  [ 26.4     4.3     7.4     0.576   3.9  ]
#  [  1.3     0.5     1.4     0.574   0.1  ]
#  [  1.3     0.1     0.1     0.541  -4.   ]
#  [  8.1     0.7     8.2     0.463  -4.5  ]
#  [  6.6     0.4     4.6     0.709  -2.1  ]
#  [  8.3     2.7     1.      0.557  -5.9  ]
#  [ 24.      4.3     4.4     0.558   1.9  ]
#  [  9.8     1.1     2.3     0.579  -1.3  ]
#  [ 11.9     2.4     8.4     0.566   1.2  ]
#  [ 12.6     2.      5.6     0.551   0.3  ]
#  [  7.5     1.7     2.8     0.484  -4.4  ]
#  [  5.3     2.5     1.7     0.558  -0.3  ]
#  [ 10.6     1.6     5.6     0.563  -1.6  ]
#  [  2.5     0.6     0.4     0.425  -7.2  ]
#  [  7.8     1.      2.5     0.579  -2.2  ]
#  [ 13.5     1.4    10.7     0.657   3.4  ]
#  [  4.4     1.      1.6     0.543  -2.3  ]
#  [  0.      0.      1.      0.    -25.6  ]
#  [ 22.4     7.      4.8     0.623   6.1  ]
#  [ 10.4     1.      6.4     0.511  -2.2  ]
#  [ 18.6     3.2     2.3     0.609   5.8  ]
#  [  9.2     1.8     3.1     0.542   0.4  ]
#  [ 15.4     7.3     3.9     0.532   1.3  ]
#  [  3.2     1.6     3.9     0.491   1.5  ]
#  [  5.9     0.7     3.8     0.514  -1.1  ]
#  [  6.9     3.5     2.      0.491  -0.4  ]
#  [  8.9     2.1     3.1     0.54   -1.   ]
#  [  1.8     1.      1.8     0.384  -3.8  ]
#  [  5.5     1.      1.5     0.506  -2.2  ]
#  [  1.8     0.      0.2     0.765  12.9  ]
#  [  0.4     0.4     0.2     0.143 -11.3  ]
#  [ 15.7     2.4     4.9     0.567   1.6  ]
#  [  6.2     1.      2.2     0.468  -3.7  ]
#  [  3.2     0.5     2.1     0.582   1.   ]
#  [  4.8     0.5     4.4     0.502  -3.2  ]
#  [  9.5     1.5     4.      0.486  -1.6  ]
#  [  0.3     1.3     0.      0.129 -18.6  ]
#  [  9.5     3.7     2.3     0.537   0.1  ]
#  [  1.9     0.4     3.4     0.452  -4.9  ]
#  [  4.      1.6     1.2     0.475  -4.2  ]
#  [ 13.2     1.6     7.1     0.552   2.   ]
#  [  5.5     0.8     3.4     0.512   1.7  ]
#  [  2.7     0.3     2.      0.521  -7.   ]
#  [  2.9     0.3     2.5     0.427  -3.   ]
#  [ 13.7     2.6     6.5     0.512   1.   ]
#  [  6.4     3.6     4.9     0.498  -1.8  ]
#  [  7.8     1.4     7.9     0.557  -0.7  ]
#  [ 22.1     4.6     4.8     0.559   7.9  ]
#  [  1.9     0.7     0.7     0.373  -6.4  ]
#  [  8.6     2.6     4.8     0.577   1.9  ]
#  [  1.9     0.2     2.8     0.519  -4.2  ]
#  [  1.7     1.1     1.2     0.378  -5.   ]
#  [  9.8     1.6     3.6     0.534  -0.2  ]
#  [  7.4     0.8     5.4     0.491  -3.8  ]
#  [  6.4     0.6     5.      0.567  -2.7  ]
#  [ 16.      5.7     2.4     0.542  -0.7  ]
#  [ 13.5     4.4     2.4     0.511  -2.9  ]
#  [ 19.6     1.9     5.9     0.535   0.5  ]
#  [  4.3     0.2     4.5     0.585  -3.3  ]
#  [  5.7     1.      7.1     0.664   0.6  ]
#  [  1.7     0.      1.3     0.753 -12.4  ]
#  [  1.8     0.3     0.5     0.354  -4.8  ]
#  [ 12.9     2.      8.5     0.522   0.3  ]
#  [ 20.6     2.3     8.9     0.535   1.5  ]
#  [  3.6     0.2     1.9     0.451  -6.1  ]
#  [  2.1     1.      0.5     0.435  -7.8  ]
#  [  8.8     4.6     1.9     0.502  -0.9  ]
#  [ 21.8     7.6     4.7     0.523   3.6  ]
#  [ 16.9     2.8     5.9     0.583   0.5  ]
#  [  1.9     0.1     0.7     0.599  -5.6  ]
#  [  8.9     0.7     3.3     0.555   0.1  ]
#  [ 10.9     1.2     2.7     0.613  -0.5  ]
#  [ 10.1     3.3     1.8     0.51   -1.6  ]
#  [ 12.3     2.5     2.9     0.538  -1.5  ]
#  [  6.7     2.8     2.      0.528  -3.1  ]
#  [  0.7     0.7     0.3     0.143 -13.   ]
#  [  6.7     2.1     1.6     0.538  -1.1  ]
#  [  3.3     1.1     1.1     0.444  -4.7  ]
#  [  9.1     2.1     3.6     0.484   0.6  ]
#  [ 11.2     4.6     2.1     0.542  -2.   ]
#  [ 12.8     2.      4.7     0.511  -0.6  ]
#  [  3.8     1.3     3.1     0.465  -3.2  ]
#  [  5.9     4.9     2.6     0.471  -0.7  ]
#  [ 10.2     1.7     3.4     0.528  -2.3  ]
#  [ 17.3     5.1     3.5     0.486   1.4  ]
#  [  4.1     0.5     1.5     0.507  -0.8  ]
#  [  2.5     0.8     2.7     0.549  -0.2  ]
#  [ 11.3     0.9     5.6     0.558  -3.6  ]
#  [ 18.5     3.7     4.8     0.551   5.   ]
#  [  4.4     0.8     4.6     0.615  -1.8  ]
#  [ 10.1     1.7     8.      0.517  -0.7  ]
#  [  0.      0.      0.7     0.    -12.7  ]
#  [ 14.2     5.7     2.3     0.531  -0.3  ]
#  [  5.7     3.6     2.3     0.51   -1.9  ]
#  [ 13.9     1.1     9.1     0.542  -1.   ]
#  [ 17.      2.8     6.      0.538   1.9  ]
#  [  9.4     0.7     6.      0.517  -1.3  ]
#  [  5.8     1.6     1.5     0.466  -1.5  ]
#  [  2.4     1.6     0.8     0.375  -4.8  ]
#  [  6.1     0.5     5.5     0.514  -1.9  ]
#  [ 11.5     2.9     4.      0.455  -3.4  ]
#  [  9.3     0.6     6.8     0.478  -2.8  ]
#  [  6.6     1.4     2.6     0.487  -2.9  ]
#  [  3.9     0.3     3.3     0.515  -2.5  ]
#  [ 22.7     4.1     5.9     0.459  -1.4  ]
#  [  3.6     0.6     2.4     0.457  -1.2  ]
#  [  9.2     1.8     3.4     0.528   0.3  ]
#  [ 17.1     1.6     6.5     0.492  -3.8  ]
#  [  9.2     1.3     1.7     0.624   3.4  ]
#  [  7.1     0.5     7.      0.558   1.7  ]
#  [  3.1     0.7     1.9     0.47   -2.   ]
#  [ 14.1     6.4     3.2     0.561   1.7  ]
#  [  4.2     0.3     2.      0.467  -5.6  ]
#  [  2.1     0.6     1.1     0.423  -2.1  ]
#  [  7.9     1.5     6.3     0.464  -2.5  ]
#  [ 13.      3.8     3.4     0.533   1.1  ]
#  [ 15.3     2.2     3.5     0.491  -1.4  ]
#  [  3.8     0.8     1.      0.475  -1.3  ]
#  [  1.7     0.3     1.8     0.444 -11.3  ]
#  [  4.1     0.9     3.3     0.477  -0.9  ]
#  [  0.4     0.      1.5     0.207 -11.   ]
#  [ 14.8     2.2     3.      0.531  -1.1  ]
#  [  4.7     0.9     2.3     0.531  -1.1  ]
#  [ 18.9     2.7     4.8     0.543   1.4  ]
#  [ 13.3     1.4     7.4     0.506  -3.7  ]
#  [  2.2     0.1     2.2     0.556  -5.8  ]
#  [ 12.4     4.3     1.7     0.612   0.8  ]
#  [  1.      0.      0.4     0.46   -7.5  ]
#  [  8.1     1.7     6.1     0.492  -0.5  ]
#  [  8.6     1.6     4.4     0.488  -2.3  ]
#  [ 10.9     1.2     6.1     0.555  -3.   ]
#  [  4.6     0.4     3.4     0.526  -5.4  ]
#  [ 12.5     1.5     2.4     0.562  -0.5  ]
#  [  3.2     0.7     6.1     0.468  -2.5  ]
#  [  1.8     1.8     1.      0.438  -6.6  ]
#  [  3.      0.      1.      1.042  -0.9  ]
#  [  9.8     1.3     5.1     0.564  -0.1  ]
#  [  1.9     0.3     0.8     0.42   -4.7  ]
#  [ 10.1     2.4     5.      0.52   -0.7  ]
#  [  5.8     3.      1.7     0.528  -2.1  ]
#  [  7.5     5.3     4.2     0.527   4.1  ]
#  [  2.4     0.2     1.4     0.541  -5.3  ]
#  [  8.7     7.5     1.9     0.556   1.5  ]
#  [  4.4     0.6     2.3     0.529  -3.   ]
#  [  8.      1.6     2.7     0.531  -1.6  ]
#  [  9.7     2.5     1.8     0.534   1.9  ]
#  [  4.5     1.      4.1     0.55   -0.9  ]
#  [  7.1     1.7     3.1     0.608  -0.3  ]
#  [  6.3     1.7     1.1     0.6     2.4  ]
#  [  5.4     0.4     4.6     0.428  -6.3  ]
#  [ 20.      2.      7.7     0.535   0.   ]
#  [  3.5     0.3     1.4     0.411  -7.2  ]
#  [  7.      8.3     2.7     0.497   1.2  ]]

# %%
print(len(non_roy_stats))
# Out:
# 155

# %%
labels = []
for i in range(len(roy_stats)):
    labels.append(1)

for i in range(len(non_roy_stats)):
    labels.append(0)

# %%
from sklearn.model_selection import train_test_split

x_data = np.concatenate((roy_stats, non_roy_stats), axis=0)
x_data = np.nan_to_num(x_data, nan=0)
y_data = np.array(labels)

x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, test_size=0.2, random_state=42)

# %%
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
SVC_classifier = SVC(probability=True)
SVC_classifier.fit(x_train, y_train)

LR_classifier = LogisticRegression()
LR_classifier.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
SVC_predictions = SVC_classifier.predict(x_test)
SVC_score = SVC_classifier.score(x_test, y_test)

LR_predictions = LR_classifier.predict(x_test)
LR_score = LR_classifier.score(x_test, y_test)

print ('SVC Score: ' + str(SVC_score))

print('LR Score: ' + str(LR_score))
# Out:
# SVC Score: 0.8108108108108109
# LR Score: 0.8918918918918919

# %%
import pickle
pickle.dump(SVC_classifier, open('ROY_classifier.pkl', 'wb'))
